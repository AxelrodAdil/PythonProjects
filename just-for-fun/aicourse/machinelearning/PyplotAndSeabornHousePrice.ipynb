# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

df = pd.read_csv('House_Price.csv')
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.581772   10516.828082     6.099315     5.575342
# std      42.300571    22.886204    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    60.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    70.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   104.244939   443.639726    46.549315  ...
# std      30.202904     20.645407   180.871060   456.098091   161.319273  ...
# ...

# %%
print("Average sales: ", round(df['HousePrice'].mean(), 5))
# Out:
# Average sales:  0.38356

# %%
sns.countplot(x=df['HousePrice'])
# Out:
# <AxesSubplot: xlabel='HousePrice', ylabel='count'>

# %%
sns.countplot(x=df['HousePrice'], hue=df['YrSold'])
# Out:
# <AxesSubplot: xlabel='HousePrice', ylabel='count'>

# %%
df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
df.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'X1stFlrSF', 'X2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'X3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'HousePrice'],
#       dtype='object')

# %%
# Data fields:

# SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# MSSubClass: The building class
# MSZoning: The general zoning classification
# LotFrontage: Linear feet of street connected to property
# LotArea: Lot size in square feet
# Street: Type of road access
# Alley: Type of alley access
# LotShape: General shape of property
# LandContour: Flatness of the property
# Utilities: Type of utilities available
# LotConfig: Lot configuration
# LandSlope: Slope of property
# Neighborhood: Physical locations within Ames city limits
# Condition1: Proximity to main road or railroad
# Condition2: Proximity to main road or railroad (if a second is present)
# BldgType: Type of dwelling
# HouseStyle: Style of dwelling
# OverallQual: Overall material and finish quality
# OverallCond: Overall condition rating
# YearBuilt: Original construction date
# YearRemodAdd: Remodel date
# RoofStyle: Type of roof
# RoofMatl: Roof material
# Exterior1st: Exterior covering on house
# Exterior2nd: Exterior covering on house (if more than one material)
# MasVnrType: Masonry veneer type
# MasVnrArea: Masonry veneer area in square feet
# ExterQual: Exterior material quality
# ExterCond: Present condition of the material on the exterior
# Foundation: Type of foundation
# BsmtQual: Height of the basement
# BsmtCond: General condition of the basement
# BsmtExposure: Walkout or garden level basement walls
# BsmtFinType1: Quality of basement finished area
# BsmtFinSF1: Type 1 finished square feet
# BsmtFinType2: Quality of second finished area (if present)
# BsmtFinSF2: Type 2 finished square feet
# BsmtUnfSF: Unfinished square feet of basement area
# TotalBsmtSF: Total square feet of basement area
# Heating: Type of heating
# HeatingQC: Heating quality and condition
# CentralAir: Central air conditioning
# Electrical: Electrical system
# 1stFlrSF: First Floor square feet
# 2ndFlrSF: Second floor square feet
# LowQualFinSF: Low quality finished square feet (all floors)
# GrLivArea: Above grade (ground) living area square feet
# BsmtFullBath: Basement full bathrooms
# BsmtHalfBath: Basement half bathrooms
# FullBath: Full bathrooms above grade
# HalfBath: Half baths above grade
# Bedroom: Number of bedrooms above basement level
# Kitchen: Number of kitchens
# KitchenQual: Kitchen quality
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# Functional: Home functionality rating
# Fireplaces: Number of fireplaces
# FireplaceQu: Fireplace quality
# GarageType: Garage location
# GarageYrBlt: Year garage was built
# GarageFinish: Interior finish of the garage
# GarageCars: Size of garage in car capacity
# GarageArea: Size of garage in square feet
# GarageQual: Garage quality
# GarageCond: Garage condition
# PavedDrive: Paved driveway
# WoodDeckSF: Wood deck area in square feet
# OpenPorchSF: Open porch area in square feet
# EnclosedPorch: Enclosed porch area in square feet
# 3SsnPorch: Three season porch area in square feet
# ScreenPorch: Screen porch area in square feet
# PoolArea: Pool area in square feet
# PoolQC: Pool quality
# Fence: Fence quality
# MiscFeature: Miscellaneous feature not covered in other categories
# MiscVal: $Value of miscellaneous feature
# MoSold: Month Sold
# YrSold: Year Sold
# SaleType: Type of sale
# SaleCondition: Condition of sale

# %%
unfinished_basement = (df['BsmtUnfSF']).sum()
print(unfinished_basement)
finished_basement_1 = (df['BsmtFinSF1']).sum()
print(finished_basement_1)
finished_basement_2 = (df['BsmtFinSF2']).sum()
print(finished_basement_2)
# Out:
# 828171
# 647714
# 67962

# %%
labels = ['Unfinished-Basement', 'Finished-Basement-1', 'Finished-Basement-2']
sizes = [unfinished_basement, finished_basement_1, finished_basement_2]
plt.pie(sizes, labels=labels, autopct='%1.2f%%')
plt.axis('equal')
plt.title('Distribution depending on the condition of the basement')
plt.show()

# %%
sns.kdeplot(df.TotalBsmtSF[df.HousePrice == 0], label='UsSold')
sns.kdeplot(df.TotalBsmtSF[df.HousePrice == 1], fill=True, label='Sold')
# Out:
# <AxesSubplot: xlabel='TotalBsmtSF', ylabel='Density'>

# %%
sns.kdeplot(df.YrSold[df.HousePrice == 0], label='UsSold')
sns.kdeplot(df.YrSold[df.HousePrice == 1], label='Sold')
# Out:
# <AxesSubplot: xlabel='YrSold', ylabel='Density'>

# %%
df.hist(column='OverallQual')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Overall-Quality')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(df['YearBuilt'], df['LotArea'])
plt.title('YearBuilt and LotArea')
plt.xlabel('YearBuilt')
plt.ylabel('LotArea')
plt.show()

# %%
quality_above_5_sold = ((df['OverallQual'] >= 6) & (df['HousePrice'] == 1)).sum()
print(quality_above_5_sold)
quality_above_5_unsold = ((df['OverallQual'] >= 6) & (df['HousePrice'] == 0)).sum()
print(quality_above_5_unsold)
quality_equal_or_below_5_sold = ((df['OverallQual'] <= 5) & (df['HousePrice'] == 1)).sum()
print(quality_equal_or_below_5_sold)
quality_equal_or_below_5_unsold = ((df['OverallQual'] <= 5) & (df['HousePrice'] == 0)).sum()
print(quality_equal_or_below_5_unsold)

data_sold = (quality_equal_or_below_5_sold, quality_above_5_sold)
data_unsold = (quality_equal_or_below_5_unsold, quality_above_5_unsold)
p1 = plt.bar(np.arange(2), (data_sold), width=0.4)
p2 = plt.bar(np.arange(2), (data_unsold), bottom=data_sold, width=0.4)
plt.xticks(np.arange(2), ['Sold', 'Unsold'])
plt.legend((p1[0], p2[0]), ('Below', 'Above'))
plt.show()
# Out:
# 541
# 381
# 19
# 519

# %%
sns.heatmap(df.corr().abs())
# Out:
# <AxesSubplot: >

# %%
plt.plot(df.YrSold, df.Fireplaces, 'r.-')
# plt.plot(df.YrSold, df.OverallCond, 'b.-', label='OverallCond')

# %%
sns.scatterplot(x='YrSold', y='LotArea', data=df)
# Out:
# <AxesSubplot: xlabel='YrSold', ylabel='LotArea'>

# %%
sns.histplot(df['GarageArea'], kde=True, bins=10)
# Out:
# <AxesSubplot: xlabel='GarageArea', ylabel='Count'>

# %%
sns.lineplot(x='HousePrice', y='TotalBsmtSF', data=df)
# Out:
# <AxesSubplot: xlabel='HousePrice', ylabel='TotalBsmtSF'>

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=df.drop(['HousePrice'], axis=1))
plt.show()

# %%
sns.barplot(x='YrSold',y='BsmtFinSF1', data=df, hue='HousePrice')
# Out:
# <AxesSubplot: xlabel='YrSold', ylabel='BsmtFinSF1'>

# %%
sns.relplot(data=df,x='YrSold',y='GarageArea',kind='scatter',col='HousePrice')

# %%
sns.displot(data=df,x='HousePrice',kind='hist',bins=2)

# %%
plt.figure(figsize=(5,5), dpi=100)

above_10 = df.loc[df['TotRmsAbvGrd'] >= 10]['OverallQual']
above_6 = df.loc[(df['TotRmsAbvGrd'] >= 6) & (df['TotRmsAbvGrd'] < 10)]['OverallQual']
below_6 = df.loc[df['TotRmsAbvGrd'] < 6]['OverallQual']

bp = plt.boxplot([above_10, above_6, below_6], labels=['above_10', 'above_6', 'below_6'], patch_artist=True)
plt.title('House-Price-TotRmsAbvGrd')
plt.ylabel('OverallQual')

for box in bp['boxes']:
    box.set(color='#6a0dad', linewidth=2)
    box.set(facecolor='#008000')

plt.show()

# %%
df.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'X1stFlrSF', 'X2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'X3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'HousePrice'],
#       dtype='object')

# %%
sns.jointplot(x='YearBuilt', y='OverallCond', data=df)

# %%
sns.jointplot(x='YearBuilt', y='OverallCond', data=df, kind='kde', fill=True)

# %%
sns.pairplot(df, hue='YearBuilt')

# %%
# from mpl_toolkits.mplot3d import Axes3D
# import numpy as np
#
# def randrange(n, vmin, vmax):
#     return (vmax - vmin)*np.random.rand(n) + vmin
#
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
#
# n = 397
# for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
#     xs = auto_data.cylinders
#     ys = auto_data.mpg
#     zs = auto_data.year
#     ax.scatter(xs, ys, zs, c=c, marker=m)
#
# ax.set_xlabel('X mpg')
# ax.set_ylabel('Y cylinders')
# ax.set_zlabel('Z acceleration')
# plt.show()

# %%
import plotly.express as px

fig = px.line(df, y='LotArea', color='HousePrice')
fig.show()
# Out:
# <div>                            <div id="99cb1cba-a1b8-4096-9a39-a627fb478da1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99cb1cba-a1b8-4096-9a39-a627fb478da1")) {                    Plotly.newPlot(                        "99cb1cba-a1b8-4096-9a39-a627fb478da1",                        [{"hovertemplate":"HousePrice=1<br>index=%{x}<br>LotArea=%{y}<extra></extra>","legendgroup":"1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","showlegend":true,"x":[0,1,2,4,6,7,11,13,20,22,25,27,28,34,35,45,46,47,53,57,58,62,64,65,67,69,70,72,80,82,85,94,95,96,100,103,105,109,112,113,114,118,124,130,131,133,138,139,141,143,147,151,152,153,157,158,159,161,162,166,167,168,169,171,172,174,175,176,178,181,183,185,189,
# ...
